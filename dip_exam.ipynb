# %% [markdown]
# # NEAF DIP EXAM
# name:

# %% [markdown]
# ---
# ### Please achieve the following image transformation: change image A into image B.

# %% [markdown]
# ### keywords:
# cv2.blur(img, (3, 3))
# cv2.dilate(img, kernel)
# cv2.inRange(img, np.array([16, 26, 120]), np.array([74, 255, 255]))
# cv2.equalizeHist(gray_img)
# cv2.bitwise_and(img1, img2, mask)
# cv2.IMREAD_GRAYSCALE
# cv2.drawContours(img, contours, -1, (0, 255, 0), 1)
# cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)
# cv2.rectangle(result, (X, Y), (X+W, Y+H), (0, 0, 255), 2)
# cv2.medianBlur(img, 3)
# cv2.boundingRect
# cv2.morphologyEx(img, cv2.MORPH_CLOSE, kernel)
# cv2.threshold(img, 0, 255, cv2.THRESH_BINARY+cv2.THRESH_OTSU)
# cv2.findContours(img, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
# cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
# cv2.getStructuringElement(cv2.MORPH_RECT, (3, 3))
# cv2.imwrite('123.jpg', img)
# cv2.GaussianBlur(img, (5, 5), 0)
# cv2.erode(img, kernel)
# cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
# cv2.contourArea(contour)

# %% [markdown]
# ---

# %% [markdown]
# ### library

# %%
from matplotlib import pyplot as plt
import numpy as np
import cv2

# %% [markdown]
# ---

# %% [markdown]
# ### 1. (5%)
# #### fig.a
# <img src="img/5.jpg" width="20%" heught="20%">
#
# #### fig.b
# <img src="img/6.jpg" width="20%" heught="20%">

# %%
# read image
img_a = cv2.imread("img/5.jpg", -1)
img_a = cv2.cvtColor(img_a, cv2.COLOR_BGR2RGB)
ori_gray = cv2.cvtColor(img_a, cv2.COLOR_RGB2GRAY)
# plt.subplot(2,2,1)
# plt.imshow(img_a,cmap='gray')
# plt.title("origin")
# plt.axis("off")
# hist1 = cv2.calcHist([img_a], [0], None, [256], [0, 256])
# plt.subplot(2,2,2)
# plt.bar(range(256), hist1.flatten(), width=1)

equalize_img = cv2.equalizeHist(ori_gray)

_, img_b = cv2.threshold(ori_gray, 50, 255, cv2.THRESH_BINARY) ## (threshold, image)
print("_ = ", _)
# plt.subplot(2,2,3)
# plt.imshow(image_binary1,cmap="gray")
# plt.title("threshold")
# plt.axis("off")

# hist2 = cv2.calcHist([image_binary1], [0], None, [256], [0, 256])
# plt.subplot(2,2,4)
# plt.bar(range(256), hist2.flatten(), width=2)
'''
enter your code
'''
# show image
plt.imshow(img_a)
plt.show()
plt.imshow(img_b,cmap="gray")
plt.show()
# Out:
# _ =  50.0

# %% [markdown]
# ---

# %% [markdown]
# ### 2. (5%)
# #### fig.a
# <img src="img/1.jpg" width="15%" heught="15%">
#
# #### fig.b
# <img src="img/2.jpg" width="15%" heught="15%">

# %%
# read image
img_a = cv2.imread("img/1.jpg",cv2.IMREAD_GRAYSCALE )


img_b = cv2.equalizeHist(img_a)



'''
enter your code
'''

# show image
plt.imshow(img_a, 'gray')
plt.axis("off")
plt.show()
plt.imshow(img_b, 'gray')
plt.axis("off")
plt.show()

# %% [markdown]
# ---

# %% [markdown]
# ### 3. (5%)
# #### a圖
# <img src="img/3.jpg" width="20%" heught="20%">
#
# #### b圖
# <img src="img/4.jpg" width="20%" heught="20%">

# %%
# read image
img_a = cv2.imread("img/3.jpg", cv2.IMREAD_GRAYSCALE)

img_b = cv2.medianBlur(img_a, 3)

# show image
plt.imshow(img_a,cmap='gray')
plt.axis("off")
plt.show()
plt.imshow(img_b,cmap='gray')
plt.axis("off")
plt.show()

# %% [markdown]
# ### 4. (10%)
# #### fig.a
# <img src="img/7.jpg" width="20%" heught="20%">
#
# #### fig.b
# <img src="img/8.jpg" width="20%" heught="20%">
#
# 1. Find the Beluga Whale contours in the  images.(5%)
# 2. Calculate the countours area.(5%)

# %%
img_a = cv2.imread("img/7.jpg")
img_a = cv2.cvtColor(img_a, cv2.COLOR_BGR2RGB)
img_b = cv2.cvtColor(img_a, cv2.COLOR_RGB2GRAY)

# plt.subplot(121)
# plt.imshow(ori_gray,cmap="gray")
# plt.title("origin")
# plt.axis("off")
# hist1 = cv2.calcHist([ori_gray], [0], None, [256], [0, 256])
# plt.subplot(2,2,2)
# plt.bar(range(256), hist1.flatten(), width=1)

_, image_binary = cv2.threshold(img_b, 60, 255, cv2.THRESH_BINARY) ## (threshold, image)
kernel = np.ones((5, 5), np.uint8)
dilated_img = cv2.dilate(image_binary, kernel, iterations=2)
eroded_img = cv2.erode(dilated_img, kernel, iterations=2)


# plt.subplot(2,2,3)
# plt.imshow(eroded_img,cmap="gray")
# plt.title("threshold")
# plt.axis("off")
contours, hierarchy = cv2.findContours(eroded_img, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)  #cv2.RETR_EXTERNAL #cv2.RETR_TREE
img_b = cv2.cvtColor(img_b, cv2.COLOR_BGR2RGB)
print(hierarchy)
cv2.drawContours(img_b,contours, -1, (255,0,0),4)
# plt.subplot(2,2,4)
# plt.imshow(img_a,cmap="gray")
# plt.title("threshold")
# plt.axis("off")
for i in range(len(contours)):
    area = cv2.contourArea(contours[i])
'''
enter your code
'''

# show image
plt.imshow(img_a,cmap="gray")
plt.show()
plt.imshow(img_b)
plt.show()
print('The Beluga Whale area is ',area)
# Out:
# [[[ 1 -1 -1 -1]
#   [ 2  0 -1 -1]
#   [-1  1 -1 -1]]]
# The Beluga Whale area is  470579.0
